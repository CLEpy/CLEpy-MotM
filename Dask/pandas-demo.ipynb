# %% [markdown]
# # Import Statement

# %%
import pandas as pd

# %% [markdown]
# # Basics

# %%
# %%time
df = pd.read_csv('sample_data.csv')
# Out:
# CPU times: user 22.1 s, sys: 9.06 s, total: 31.2 s
# Wall time: 35 s

# %% [markdown]
# ## Bonus: Parquet

# %%
# %%time
df = pd.read_parquet('sample_data_parquet')
# Out:
# CPU times: user 7.31 s, sys: 9.37 s, total: 16.7 s
# Wall time: 12.9 s

# %%
df.head()
# Out:
#                          alphabet useless_letter   Z   Y   X   W   V   U   T  \
# index
# 0      ABCDEFGHIJKLMNOPQRSTUVWXYZ              U   1  66  69   4  70  64  83
# 1      ABCDEFGHIJKLMNOPQRSTUVWXYZ              L  25  26  36  34   0  75  60
# 2      ABCDEFGHIJKLMNOPQRSTUVWXYZ              N  40  67  36  54  46   5  57
# 3      ABCDEFGHIJKLMNOPQRSTUVWXYZ              C  91  98   8  36  17   3  29
# 4      ABCDEFGHIJKLMNOPQRSTUVWXYZ              J  87  68  73  78  39  67  57
#
#         S  ...   J   I   H   G   F   E   D   C   B   A
# index      ...
# 0      55  ...  36  28  33  57  23  86  48  30  91  84
# 1      73  ...  42  91   8  24  64  13  43  47  94  11
# 2      50  ...  82  76  24  60   3  55  64  28  26  89
# 3      90  ...  88  24   7  51  52  87   1   6  19  48
# 4      24  ...   9  14   0   2  51  18  95  71  28  13
#
# [5 rows x 28 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#                            alphabet useless_letter   Z   Y   X   W   V   U  \
# index
# 0        ABCDEFGHIJKLMNOPQRSTUVWXYZ              U   1  66  69   4  70  64
# 1        ABCDEFGHIJKLMNOPQRSTUVWXYZ              L  25  26  36  34   0  75
# 2        ABCDEFGHIJKLMNOPQRSTUVWXYZ              N  40  67  36  54  46   5
# 3        ABCDEFGHIJKLMNOPQRSTUVWXYZ              C  91  98   8  36  17   3
# 4        ABCDEFGHIJKLMNOPQRSTUVWXYZ              J  87  68  73  78  39  67
# ...                             ...            ...  ..  ..  ..  ..  ..  ..
# 8999995  ABCDEFGHIJKLMNOPQRSTUVWXYZ              F  14   6  87  54  44  93
# 8999996  ABCDEFGHIJKLMNOPQRSTUVWXYZ              F   3  86  73   6  47  72
# 8999997  ABCDEFGHIJKLMNOPQRSTUVWXYZ              U   6  88  22  17   0  18
# 8999998  ABCDEFGHIJKLMNOPQRSTUVWXYZ              V  14  97   6   5   4  55
# 8999999  ABCDEFGHIJKLMNOPQRSTUVWXYZ              N   5  76  72  99  50  42
#
#           T   S  ...   J   I   H   G   F   E   D   C   B   A
# ...

# %% [markdown]
# ## Computation

# %%
# %%time
df['mean'] = df.mean(axis=1)
# Out:
# CPU times: user 36.7 s, sys: 45.7 s, total: 1min 22s
# Wall time: 1min 56s
