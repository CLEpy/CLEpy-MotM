# %% [markdown]
# # selectolax
#
# Fastest HTML Parser for python (that I know of).\
# Many times faster than Beautiful Soup.
#
# https://github.com/rushter/selectolax
#
# # What's Behind It?
# Useses Modest backend by default. \
# Modest is a HTML parser written entirely in C.\
# https://github.com/lexborisov/modest\
# Lexbor as the other option.\
# https://github.com/lexbor/lexbor\
# The author wrote lexbor more recently, but the selectolax readme says it's still in beta.\
# The lexbor readme says it's stable and we should use it. Lexbor seems to be better maintained with lots of recent commits from that guy. Most examples will be using the Modest, but we'll do a speed test at the end with lexbor too.
#
#
# # View method definitions
# selectolax uses Cython to extend Modest and Lexbor.
# The docstrings are in the .pxi and .pyx files.
#
# HTMLParser - https://github.com/rushter/selectolax/blob/master/selectolax/parser.pyx
#
# Node - https://github.com/rushter/selectolax/blob/master/selectolax/modest/node.pxi
#
# Selection - https://github.com/rushter/selectolax/blob/master/selectolax/modest/selection.pxi

# %%
from selectolax.parser import HTMLParser
from selectolax.lexbor import LexborHTMLParser

import requests
from pathlib import Path

from bs4 import BeautifulSoup
from parsel import Selector
from selectolax.parser import HTMLParser

# %%
# Webpage
r = requests.get("https://en.wikipedia.org/wiki/John_D._Rockefeller")

# %% [markdown]
# # HTMLParser

# %%
tree = HTMLParser(r.text)
tree, type(tree)
# Out:
# (<HTMLParser chars=390526>, selectolax.parser.HTMLParser)

# %% [markdown]
# ```
# .css()
# ```
# Returns list of Nodes

# %%
tree.css("h2")  # -> list[Node]
# Out:
# [<Node h2>,
#  <Node h2>,
#  <Node h2>,
#  <Node h2>,
#  <Node h2>,
#  <Node h2>,
#  <Node h2>,
#  <Node h2>,
#  <Node h2>,
#  <Node h2>,
#  <Node h2>,
#  <Node h2>,
#  <Node h2>,
#  <Node h2>,
#  <Node h2>]

# %%
for node in tree.css("h2"):
    print(node.text())
# Out:
# Contents
# Early life
# Pre-Standard Oil career
# Standard Oil
# Colorado Fuel and Iron
# Personal life
# Philanthropy
# Florida home
# Illnesses and death
# Legacy
# See also
# Explanatory notes
# Citations
# General bibliography
# External links

# %% [markdown]
# ```
# .css_first()
# ```
# Returns Node

# %%
tree.css_first("h2")  # -> Node
# Out:
# <Node h2>

# %%
tree.css_first("h2").text()
# Out:
# 'Contents'

# %% [markdown]
# ```
# .select()
# ```
# returns Selection object

# %%
tree.select("div")

# %% [markdown]
# Chain selection to search further down

# %%
tree_1 = HTMLParser(
    """
    <div>
        <a class="thisone" href="www.google.com">a tag!</a>
        <span>span tag!</span>
    </div>
"""
)
tree_1.select("div").css(".thisone").matches
# Out:
# [<Node a>]

# %% [markdown]
# Tree Attributes

# %%
tree.head, tree.body, tree.root, tree.input_encoding
# Out:
# (<Node head>, <Node body>, <Node html>, 'UTF-8')

# %% [markdown]
# Tree checks

# %%
tree.scripts_contain("Namespace"), tree.css_matches("a")
# Out:
# (True, True)

# %% [markdown]
# Tags
# ```
# .tags()
# ```

# %% [markdown]
# Tags vs select

# %%
# %%timeit
tree.tags("a")
# Out:
# 100 µs ± 460 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
tree.select("a").matches
# Out:
# 145 µs ± 857 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# Tags vs select with more specific attributes
#
# Getting just tags is faster, but when you need to search for something more specific, you'll save time by using .css() or .select()

# %%
# %%timeit
[node for node in tree.tags("a") if node.attributes.get('href') == 'https://web.archive.org/web/20110722233117/http://www.cpu.edu.ph/infocen/October05.htm']
# Out:
# 1.44 ms ± 6.78 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit
[node for node in tree.select(".mw-references-columns a[href]").matches if node.attributes.get('href') == 'https://web.archive.org/web/20110722233117/http://www.cpu.edu.ph/infocen/October05.htm']
# Out:
# 449 µs ± 6.42 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# # Nodes

# %%
node = tree.css("div.hatnote")[0]
node
# Out:
# <Node div>

# %% [markdown]
# ```html
# <div role="note" class="hatnote navigation-not-searchable">For other people named John D. Rockefeller, see
#     <a href="/wiki/John_D._Rockefeller_(disambiguation)" class="mw-disambig"
#         title="John D. Rockefeller (disambiguation)">John D. Rockefeller (disambiguation)</a>.
# </div>
# ```

# %% [markdown]
# Shares many methods and attributes as the tree - .css(), .css_first(), .select(), etc

# %%
node.css("a")[0], node.css_first("a"), node.select("a")
# Out:
# (<Node a>, <Node a>, <selectolax.parser.Selector at 0x7fd3692a6380>)

# %% [markdown]
# ```
# .attributes
# ```

# %%
node.attributes
# Out:
# {'role': 'note', 'class': 'hatnote navigation-not-searchable'}

# %%
node.attributes["role"]
# Out:
# 'note'

# %% [markdown]
# ```
# .text()
# ```

# %%
node.text()
# Out:
# 'For other people named John D. Rockefeller, see John D. Rockefeller (disambiguation).'

# %%
node.text(deep=False)
# Out:
# 'For other people named John D. Rockefeller, see .'

# %% [markdown]
# Relatives

# %%
node.parent, node.child, node.last_child
# Out:
# (<Node div>, <Node -text>, <Node -text>)

# %%
node.next, node.prev
# Out:
# (<Node -text>, <Node style>)

# %%
for i in node.iter():
    print(i)
# Out:
# <Node a>

# %%
for i in node.traverse():
    print(i)
# Out:
# <Node div>
# <Node a>
# <Node p>
# <Node style>
# <Node table>
# <Node tbody>
# <Node tr>
# <Node th>
# <Node div>
# <Node tr>
# <Node td>
# <Node a>
# <Node img>
# <Node div>
# <Node tr>
# <Node th>
# <Node td>
# <Node div>
# <Node br>
# <Node span>
# <Node span>
# <Node br>
# <Node div>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node span>
# <Node br>
# <Node div>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node a>
# <Node style>
# <Node span>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node span>
# <Node span>
# <Node span>
# <Node span>
# <Node span>
# <Node span>
# <Node tr>
# <Node th>
# <Node td>
# <Node style>
# <Node div>
# <Node ul>
# <Node li>
# <Node li>
# <Node tr>
# <Node th>
# <Node td>
# <Node a>
# <Node div>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node div>
# <Node div>
# <Node a>
# <Node div>
# <Node div>
# <Node abbr>
# <Node wbr>
# <Node tr>
# <Node th>
# <Node td>
# <Node link>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node li>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node style>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node li>
# <Node tr>
# <Node th>
# <Node td>
# <Node a>
# <Node p>
# <Node b>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node p>
# <Node sup>
# <Node a>
# <Node a>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node i>
# <Node a>
# <Node span>
# <Node sup>
# <Node a>
# <Node sup>
# <Node i>
# <Node a>
# <Node span>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node meta>
# <Node h2>
# <Node span>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node h2>
# <Node span>
# <Node h3>
# <Node span>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node h3>
# <Node span>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node sup>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node i>
# <Node a>
# <Node span>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node h3>
# <Node span>
# <Node p>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node i>
# <Node a>
# <Node span>
# <Node h2>
# <Node span>
# <Node link>
# <Node div>
# <Node a>
# <Node h3>
# <Node span>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node abbr>
# <Node span>
# <Node p>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node sup>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node sup>
# <Node a>
# <Node sup>
# <Node i>
# <Node a>
# <Node span>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node p>
# <Node b>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node sup>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node style>
# <Node blockquote>
# <Node p>
# <Node a>
# <Node div>
# <Node cite>
# <Node sup>
# <Node a>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node blockquote>
# <Node p>
# <Node h3>
# <Node span>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node a>
# <Node p>
# <Node i>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node i>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node a>
# <Node p>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node sup>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node i>
# <Node a>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node i>
# <Node a>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node i>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node i>
# <Node a>
# <Node span>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node abbr>
# <Node span>
# <Node a>
# <Node p>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node h2>
# <Node span>
# <Node p>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node h3>
# <Node span>
# <Node span>
# <Node link>
# <Node div>
# <Node a>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node h2>
# <Node span>
# <Node h3>
# <Node span>
# <Node link>
# <Node div>
# <Node a>
# <Node p>
# <Node i>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node sup>
# <Node i>
# <Node a>
# <Node span>
# <Node h3>
# <Node span>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node a>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node ul>
# <Node li>
# <Node a>
# <Node li>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node h3>
# <Node span>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node i>
# <Node a>
# <Node span>
# <Node p>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node link>
# <Node blockquote>
# <Node p>
# <Node sup>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node h2>
# <Node span>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node p>
# <Node sup>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node a>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node sup>
# <Node a>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node a>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node a>
# <Node a>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node i>
# <Node a>
# <Node sup>
# <Node i>
# <Node a>
# <Node span>
# <Node i>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node i>
# <Node a>
# <Node span>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node a>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node h2>
# <Node span>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node h2>
# <Node span>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node h2>
# <Node span>
# <Node link>
# <Node table>
# <Node tbody>
# <Node tr>
# <Node th>
# <Node tr>
# <Node td>
# <Node img>
# <Node a>
# <Node i>
# <Node i>
# <Node a>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node a>
# <Node p>
# <Node a>
# <Node a>
# <Node p>
# <Node a>
# <Node link>
# <Node blockquote>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node blockquote>
# <Node p>
# <Node sup>
# <Node a>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node link>
# <Node blockquote>
# <Node p>
# <Node sup>
# <Node a>
# <Node h3>
# <Node span>
# <Node div>
# <Node div>
# <Node a>
# <Node img>
# <Node div>
# <Node div>
# <Node a>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node p>
# <Node a>
# <Node sup>
# <Node a>
# <Node i>
# <Node a>
# <Node sup>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node a>
# <Node sup>
# <Node i>
# <Node a>
# <Node span>
# <Node p>
# <Node sup>
# <Node a>
# <Node link>
# <Node blockquote>
# <Node div>
# <Node p>
# <Node br>
# <Node br>
# <Node br>
# <Node br>
# <Node h2>
# <Node span>
# <Node ul>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node h2>
# <Node span>
# <Node style>
# <Node div>
# <Node div>
# <Node ol>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node i>
# <Node style>
# <Node span>
# <Node span>
# <Node span>
# <Node sup>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node sup>
# <Node a>
# <Node a>
# <Node sup>
# <Node a>
# <Node h2>
# <Node span>
# <Node link>
# <Node div>
# <Node div>
# <Node ol>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node style>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node a>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node a>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node i>
# <Node link>
# <Node a>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node a>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node span>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node i>
# <Node a>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node i>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node a>
# <Node i>
# <Node i>
# <Node span>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node i>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node span>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node span>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node a>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node a>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node span>
# <Node span>
# <Node q>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node a>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node i>
# <Node b>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node i>
# <Node sup>
# <Node i>
# <Node a>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node link>
# <Node cite>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node link>
# <Node cite>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node span>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node a>
# <Node sup>
# <Node i>
# <Node b>
# <Node span>
# <Node link>
# <Node cite>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node a>
# <Node i>
# <Node a>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node i>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node i>
# <Node b>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node span>
# <Node span>
# <Node span>
# <Node span>
# <Node code>
# <Node a>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node span>
# <Node span>
# <Node span>
# <Node span>
# <Node code>
# <Node a>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node i>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node i>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node span>
# <Node i>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node span>
# <Node b>
# <Node a>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node span>
# <Node span>
# <Node span>
# <Node span>
# <Node h2>
# <Node span>
# <Node style>
# <Node div>
# <Node style>
# <Node table>
# <Node tbody>
# <Node tr>
# <Node td>
# <Node div>
# <Node a>
# <Node img>
# <Node td>
# <Node div>
# <Node b>
# <Node a>
# <Node span>
# <Node span>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node span>
# <Node i>
# <Node span>
# <Node ul>
# <Node li>
# <Node link>
# <Node cite>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node a>
# <Node li>
# <Node link>
# <Node cite>
# <Node span>
# <Node a>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node i>
# <Node li>
# <Node link>
# <Node cite>
# <Node i>
# <Node span>
# <Node li>
# <Node link>
# <Node cite>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node i>
# <Node li>
# <Node i>
# <Node li>
# <Node i>
# <Node li>
# <Node link>
# <Node cite>
# <Node i>
# <Node span>
# <Node li>
# <Node link>
# <Node cite>
# <Node i>
# <Node span>
# <Node li>
# <Node link>
# <Node cite>
# <Node i>
# <Node span>
# <Node li>
# <Node i>
# <Node li>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node i>
# <Node li>
# <Node i>
# <Node li>
# <Node i>
# <Node li>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node span>
# <Node li>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node i>
# <Node li>
# <Node link>
# <Node cite>
# <Node i>
# <Node span>
# <Node li>
# <Node i>
# <Node li>
# <Node i>
# <Node a>
# <Node a>
# <Node li>
# <Node link>
# <Node cite>
# <Node a>
# <Node a>
# <Node i>
# <Node span>
# <Node li>
# <Node link>
# <Node cite>
# <Node i>
# <Node span>
# <Node li>
# <Node i>
# <Node li>
# <Node i>
# <Node a>
# <Node li>
# <Node link>
# <Node cite>
# <Node i>
# <Node span>
# <Node li>
# <Node li>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node b>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node a>
# <Node span>
# <Node li>
# <Node link>
# <Node cite>
# <Node i>
# <Node span>
# <Node li>
# <Node link>
# <Node cite>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node link>
# <Node cite>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node span>
# <Node span>
# <Node li>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node li>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node span>
# <Node li>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node span>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node span>
# <Node li>
# <Node link>
# <Node cite>
# <Node a>
# <Node i>
# <Node a>
# <Node a>
# <Node bdi>
# <Node span>
# <Node h2>
# <Node span>
# <Node style>
# <Node style>
# <Node div>
# <Node link>
# <Node div>
# <Node b>
# <Node a>
# <Node span>
# <Node div>
# <Node div>
# <Node ul>
# <Node li>
# <Node span>
# <Node img>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node img>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node img>
# <Node span>
# <Node a>
# <Node ul>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node a>
# <Node li>
# <Node a>
# <Node a>
# <Node li>
# <Node a>
# <Node a>
# <Node img>
# <Node div>
# <Node link>
# <Node style>
# <Node div>
# <Node table>
# <Node tbody>
# <Node tr>
# <Node th>
# <Node link>
# <Node style>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node abbr>
# <Node li>
# <Node a>
# <Node abbr>
# <Node li>
# <Node a>
# <Node abbr>
# <Node div>
# <Node a>
# <Node tr>
# <Node th>
# <Node b>
# <Node a>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node tr>
# <Node th>
# <Node b>
# <Node br>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node a>
# <Node li>
# <Node a>
# <Node a>
# <Node br>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node a>
# <Node tr>
# <Node th>
# <Node b>
# <Node br>
# <Node br>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node br>
# <Node a>
# <Node br>
# <Node a>
# <Node a>
# <Node li>
# <Node a>
# <Node a>
# <Node li>
# <Node a>
# <Node a>
# <Node a>
# <Node li>
# <Node a>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node tr>
# <Node th>
# <Node br>
# <Node br>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node br>
# <Node a>
# <Node a>
# <Node li>
# <Node a>
# <Node br>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node tr>
# <Node th>
# <Node br>
# <Node br>
# <Node br>
# <Node br>
# <Node br>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node br>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node br>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node p>
# <Node br>
# <Node a>
# <Node br>
# <Node ul>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node br>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node div>
# <Node link>
# <Node link>
# <Node div>
# <Node table>
# <Node tbody>
# <Node tr>
# <Node th>
# <Node link>
# <Node link>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node abbr>
# <Node li>
# <Node a>
# <Node abbr>
# <Node li>
# <Node a>
# <Node abbr>
# <Node div>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node i>
# <Node a>
# <Node li>
# <Node i>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node li>
# <Node a>
# <Node tr>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node img>
# <Node a>
# <Node li>
# <Node img>
# <Node a>
# <Node div>
# <Node link>
# <Node link>
# <Node div>
# <Node table>
# <Node tbody>
# <Node tr>
# <Node th>
# <Node div>
# <Node a>
# <Node a>
# <Node img>
# <Node tr>
# <Node th>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node a>
# <Node ul>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node a>
# <Node ul>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node a>
# <Node ul>
# <Node li>
# <Node span>
# <Node a>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node span>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node span>
# <Node a>
# <Node tr>
# <Node th>
# <Node td>
# <Node div>
# <Node ul>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node a>
# <Node ul>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node span>
# <Node a>
# <Node ul>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node a>
# <Node ul>
# <Node li>
# <Node span>
# <Node a>
# <Node li>
# <Node a>
# <Node ul>
# <Node li>
# <Node span>
# <Node a>
# <Node style>
# <Node div>
# <Node span>
# <Node a>
# <Node ul>
# <Node li>
# <Node img>
# <Node a>
# <Node li>
# <Node a>
# <Node img>
# <Node a>
# <Node li>
# <Node a>
# <Node img>
# <Node a>
# <Node li>
# <Node img>
# <Node a>
# <Node li>
# <Node img>
# <Node a>
# <Node li>
# <Node a>
# <Node img>
# <Node a>
# <Node _comment>
# <Node _comment>
# <Node _comment>

# %% [markdown]
# # Selection
# Allows you to chain together CSS selectors and implements some convenience methods

# %% [markdown]
# ```
# .matches
# ```

# %%
# same as tree.css("#As_a_bookkeeper")
tree.select("#As_a_bookkeeper").matches
# Out:
# [<Node span>]

# %% [markdown]
# ```
# .text_contains()
# ```

# %%
tree.select("h2").text_contains("Florida home").matches
# Out:
# [<Node h2>]

# %% [markdown]
# ```
# .css()
# ```
# Returns Selection object
#
# This is different than ```tree.css()``` which returns List of Nodes
#
# The only useful think I can think of is to use it after a selection method

# %%
tree.select("div").text_contains("Rockefeller").css(".thumbcaption").matches[0].text()
# Out:
# "Rockefeller's birthplace in Richford, New York"

# %% [markdown]
# ## Advanced

# %%
# %%timeit
(
    tree.select("tr:has(th.infobox-label)")
    .text_contains("Died")
    .css("td.infobox-data") # Selection css() method returns a selector, not a node or node list 
    .matches[0]
    .text(deep=False)
)
# Out:
# 139 µs ± 1.21 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
[node.next.text(deep=False) for node in tree.select("th.infobox-label").text_contains("Died").matches][0]
# Out:
# 90.9 µs ± 901 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# # Quick Exmaples

# %% [markdown]
# Get links

# %%
[node.attrs["href"] for node in tree.css("a[href]")]
# Out:
# ['#bodyContent',
#  '/wiki/Main_Page',
#  '/wiki/Special:Search',
#  '/w/index.php?title=Special:CreateAccount&returnto=John+D.+Rockefeller',
#  '/w/index.php?title=Special:UserLogin&returnto=John+D.+Rockefeller',
#  '/w/index.php?title=Special:CreateAccount&returnto=John+D.+Rockefeller',
#  '/w/index.php?title=Special:UserLogin&returnto=John+D.+Rockefeller',
#  '/wiki/Help:Introduction',
#  '/wiki/Special:MyTalk',
#  '/wiki/Special:MyContributions',
#  '/wiki/Main_Page',
#  '/wiki/Wikipedia:Contents',
#  '/wiki/Portal:Current_events',
#  '/wiki/Special:Random',
#  '/wiki/Wikipedia:About',
#  '//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en',
#  '/wiki/Help:Contents',
#  '/wiki/Help:Introduction',
#  '/wiki/Wikipedia:Community_portal',
#  '/wiki/Special:RecentChanges',
#  '/wiki/Wikipedia:File_upload_wizard',
#  '/wiki/Special:WhatLinksHere/John_D._Rockefeller',
#  '/wiki/Special:RecentChangesLinked/John_D._Rockefeller',
#  '/wiki/Wikipedia:File_Upload_Wizard',
#  '/wiki/Special:SpecialPages',
#  '/w/index.php?title=John_D._Rockefeller&oldid=1138196481',
#  '/w/index.php?title=John_D._Rockefeller&action=info',
#  '/w/index.php?title=Special:CiteThisPage&page=John_D._Rockefeller&id=1138196481&wpFormIdentifier=titleform',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q160278',
#  '/w/index.php?title=Special:DownloadAsPdf&page=John_D._Rockefeller&action=show-download-screen',
#  '/w/index.php?title=John_D._Rockefeller&printable=yes',
#  'https://commons.wikimedia.org/wiki/John_D._Rockefeller',
#  'https://en.wikiquote.org/wiki/John_D._Rockefeller',
#  '#p-lang-btn',
#  '#',
#  '#Early_life',
#  '#Pre-Standard_Oil_career',
#  '#As_a_bookkeeper',
#  '#Business_partnership_and_Civil_War_service',
#  '#Beginning_in_the_oil_business',
#  '#Standard_Oil',
#  '#Founding_and_early_growth',
#  '#Monopoly',
#  '#Colorado_Fuel_and_Iron',
#  '#Strike_of_1913–14_and_the_Ludlow_Massacre',
#  '#Personal_life',
#  '#Family',
#  '#Marriage',
#  '#Religious_views',
#  '#Philanthropy',
#  '#Florida_home',
#  '#Illnesses_and_death',
#  '#Legacy',
#  '#Wealth',
#  '#See_also',
#  '#Explanatory_notes',
#  '#Citations',
#  '#General_bibliography',
#  '#External_links',
#  'https://af.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://ar.wikipedia.org/wiki/%D8%AC%D9%88%D9%86_%D8%AF%D8%A7%D9%81%D9%8A%D8%B3%D9%88%D9%86_%D8%B1%D9%88%D9%83%D9%81%D9%84%D8%B1',
#  'https://ast.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://az.wikipedia.org/wiki/Con_Rokfeller',
#  'https://bn.wikipedia.org/wiki/%E0%A6%9C%E0%A6%A8_%E0%A6%B0%E0%A6%95%E0%A6%AB%E0%A7%87%E0%A6%B2%E0%A6%BE%E0%A6%B0',
#  'https://zh-min-nan.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://ba.wikipedia.org/wiki/%D0%A0%D0%BE%D0%BA%D1%84%D0%B5%D0%BB%D0%BB%D0%B5%D1%80_%D0%94%D0%B6%D0%BE%D0%BD_%D0%94%D1%8D%D0%B2%D0%B8%D1%81%D0%BE%D0%BD',
#  'https://be.wikipedia.org/wiki/%D0%94%D0%B6%D0%BE%D0%BD_%D0%94%D1%8D%D0%B9%D0%B2%D1%96%D1%81%D0%B0%D0%BD_%D0%A0%D0%BE%D0%BA%D1%84%D0%B5%D0%BB%D0%B5%D1%80',
#  'https://bi.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://bg.wikipedia.org/wiki/%D0%94%D0%B6%D0%BE%D0%BD_%D0%A0%D0%BE%D0%BA%D1%84%D0%B5%D0%BB%D0%B5%D1%80',
#  'https://bo.wikipedia.org/wiki/%E0%BD%87%E0%BD%BC%E0%BD%A0%E0%BD%BC%E0%BC%8B%E0%BD%8F%E0%BD%A0%E0%BD%BA%E0%BC%8B%E0%BD%A3%E0%BE%A6%E0%BD%BA%E0%BC%8B%E0%BD%A6%E0%BD%BC%E0%BD%93%E0%BC%8B%E0%BD%A2%E0%BD%BC%E0%BD%A0%E0%BD%BC%E0%BC%8B%E0%BD%80%E0%BC%8B%E0%BD%A7%E0%BE%A5%E0%BD%BA%E0%BC%8B%E0%BD%A3%E0%BD%A2%E0%BC%8D',
#  'https://ca.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://cs.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://cy.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://da.wikipedia.org/wiki/John_D._Rockefeller,_Sr.',
#  'https://de.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://et.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://el.wikipedia.org/wiki/%CE%A4%CE%B6%CE%BF%CE%BD_%CE%9D%CF%84._%CE%A1%CE%BF%CE%BA%CF%86%CE%AD%CE%BB%CE%B5%CF%81',
#  'https://es.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://eo.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://eu.wikipedia.org/wiki/John_Davidson_Rockefeller',
#  'https://fa.wikipedia.org/wiki/%D8%AC%D8%A7%D9%86_%D8%AF%DB%8C%D9%88%DB%8C%D8%B3_%D8%B1%D8%A7%DA%A9%D9%81%D9%84%D8%B1',
#  'https://fr.wikipedia.org/wiki/John_Davison_Rockefeller',
#  'https://gl.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://gom.wikipedia.org/wiki/%E0%A4%9C%E0%A5%89%E0%A4%A8_%E0%A4%A1%E0%A5%87%E0%A4%B5%E0%A5%8D%E0%A4%B9%E0%A4%BF%E0%A4%B8%E0%A4%A8_%E0%A4%B0%E0%A5%89%E0%A4%95%E0%A4%AB%E0%A5%85%E0%A4%B2%E0%A4%B0',
#  'https://ko.wikipedia.org/wiki/%EC%A1%B4_D._%EB%A1%9D%ED%8E%A0%EB%9F%AC',
#  'https://hy.wikipedia.org/wiki/%D5%8B%D5%B8%D5%B6_%D4%B4%D6%87%D5%AB%D5%BD%D5%B8%D5%B6_%D5%8C%D5%B8%D6%84%D6%86%D5%A5%D5%AC%D5%AC%D5%A5%D6%80',
#  'https://hr.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://id.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://is.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://it.wikipedia.org/wiki/John_Davison_Rockefeller',
#  'https://he.wikipedia.org/wiki/%D7%92%27%D7%95%D7%9F_%D7%93._%D7%A8%D7%95%D7%A7%D7%A4%D7%9C%D7%A8',
#  'https://ka.wikipedia.org/wiki/%E1%83%AF%E1%83%9D%E1%83%9C_%E1%83%A0%E1%83%9D%E1%83%99%E1%83%A4%E1%83%94%E1%83%9A%E1%83%94%E1%83%A0%E1%83%98',
#  'https://kk.wikipedia.org/wiki/%D0%94%D0%B6%D0%BE%D0%BD_%D0%94%D1%8D%D0%B2%D0%B8%D1%81%D0%BE%D0%BD_%D0%A0%D0%BE%D0%BA%D1%84%D0%B5%D0%BB%D0%BB%D0%B5%D1%80',
#  'https://la.wikipedia.org/wiki/Ioannes_Rockefeller',
#  'https://lv.wikipedia.org/wiki/D%C5%BEons_Rokfellers',
#  'https://lt.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://hu.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://mk.wikipedia.org/wiki/%D0%8F%D0%BE%D0%BD_%D0%A0%D0%BE%D0%BA%D1%84%D0%B5%D0%BB%D0%B5%D1%80',
#  'https://mg.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://mr.wikipedia.org/wiki/%E0%A4%9C%E0%A5%89%E0%A4%A8_%E0%A4%A1%E0%A5%80._%E0%A4%B0%E0%A5%89%E0%A4%95%E0%A4%AB%E0%A5%87%E0%A4%B2%E0%A4%B0_%E0%A4%AA%E0%A4%B9%E0%A4%BF%E0%A4%B2%E0%A4%BE',
#  'https://arz.wikipedia.org/wiki/%D8%AC%D9%88%D9%86_%D8%AF%D8%A7%D9%81%D9%8A%D8%B3%D9%88%D9%86_%D8%B1%D9%88%D9%83%D9%81%D9%84%D8%B1',
#  'https://ms.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://my.wikipedia.org/wiki/%E1%80%82%E1%80%BB%E1%80%BD%E1%80%94%E1%80%BA_%E1%80%92%E1%80%B1%E1%80%B8%E1%80%97%E1%80%AE%E1%80%86%E1%80%94%E1%80%BA_%E1%80%9B%E1%80%B1%E1%80%AC%E1%80%B7%E1%80%80%E1%80%96%E1%80%B2%E1%80%9C%E1%80%AC%E1%80%B8',
#  'https://nl.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://ja.wikipedia.org/wiki/%E3%82%B8%E3%83%A7%E3%83%B3%E3%83%BB%E3%83%AD%E3%83%83%E3%82%AF%E3%83%95%E3%82%A7%E3%83%A9%E3%83%BC',
#  'https://no.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://nn.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://ps.wikipedia.org/wiki/%D8%AC%D8%A7%D9%86_%DA%89%D9%8A_%D8%B1%D8%A7%DA%A9%D9%81%DB%8C%D9%84%D8%B1',
#  'https://pms.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://pl.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://pt.wikipedia.org/wiki/John_Davison_Rockefeller',
#  'https://ro.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://ru.wikipedia.org/wiki/%D0%A0%D0%BE%D0%BA%D1%84%D0%B5%D0%BB%D0%BB%D0%B5%D1%80,_%D0%94%D0%B6%D0%BE%D0%BD_%D0%94%D1%8D%D0%B2%D0%B8%D1%81%D0%BE%D0%BD',
#  'https://sq.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://simple.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://sl.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://sr.wikipedia.org/wiki/%D0%8F%D0%BE%D0%BD_%D0%94._%D0%A0%D0%BE%D0%BA%D1%84%D0%B5%D0%BB%D0%B5%D1%80',
#  'https://sh.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://fi.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://sv.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://ta.wikipedia.org/wiki/%E0%AE%9C%E0%AE%BE%E0%AE%A9%E0%AF%8D_%E0%AE%9F%E0%AE%BF._%E0%AE%B0%E0%AE%BE%E0%AE%95%E0%AF%8D%E0%AE%AA%E0%AF%86%E0%AE%B2%E0%AF%8D%E0%AE%B2%E0%AE%B0%E0%AF%8D',
#  'https://th.wikipedia.org/wiki/%E0%B8%88%E0%B8%AD%E0%B8%AB%E0%B9%8C%E0%B8%99_%E0%B8%94%E0%B8%B5._%E0%B8%A3%E0%B9%87%E0%B8%AD%E0%B8%81%E0%B9%80%E0%B8%81%E0%B8%AD%E0%B8%B0%E0%B9%80%E0%B8%9F%E0%B8%A5%E0%B9%80%E0%B8%A5%E0%B8%AD%E0%B8%A3%E0%B9%8C',
#  'https://tr.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://uk.wikipedia.org/wiki/%D0%94%D0%B6%D0%BE%D0%BD_%D0%94%D0%B5%D0%B2%D1%96%D1%81%D0%BE%D0%BD_%D0%A0%D0%BE%D0%BA%D1%84%D0%B5%D0%BB%D0%BB%D0%B5%D1%80',
#  'https://ur.wikipedia.org/wiki/%D8%AC%D8%A7%D9%86_%DA%88%DB%8C_%D8%B1%D8%A7%DA%A9%D9%81%DB%8C%D9%84%D8%B1',
#  'https://vi.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://war.wikipedia.org/wiki/John_D._Rockefeller',
#  'https://wuu.wikipedia.org/wiki/%E7%BA%A6%E7%BF%B0%C2%B7%E6%88%B4%E7%BB%B4%E6%A3%AE%C2%B7%E6%B4%9B%E5%85%8B%E8%8F%B2%E5%8B%92',
#  'https://zh-yue.wikipedia.org/wiki/%E6%B4%9B%E5%85%8B%E8%8F%B2%E5%8B%92',
#  'https://zh.wikipedia.org/wiki/%E7%BA%A6%E7%BF%B0%C2%B7%E6%88%B4%E7%BB%B4%E6%A3%AE%C2%B7%E6%B4%9B%E5%85%8B%E8%8F%B2%E5%8B%92',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q160278#sitelinks-wikipedia',
#  '/wiki/John_D._Rockefeller',
#  '/wiki/Talk:John_D._Rockefeller',
#  '/wiki/John_D._Rockefeller',
#  '/w/index.php?title=John_D._Rockefeller&action=edit',
#  '/w/index.php?title=John_D._Rockefeller&action=history',
#  '/wiki/John_D._Rockefeller',
#  '/w/index.php?title=John_D._Rockefeller&action=edit',
#  '/w/index.php?title=John_D._Rockefeller&action=history',
#  '/wiki/Wikipedia:Good_articles',
#  '/wiki/Wikipedia:Protection_policy#semi',
#  '/wiki/John_D._Rockefeller_(disambiguation)',
#  '/wiki/File:Portrait_of_J._D._Rockefeller.jpg',
#  '/wiki/Richford,_New_York',
#  '/wiki/Ormond_Beach,_Florida',
#  '/wiki/Lake_View_Cemetery',
#  '//geohack.toolforge.org/geohack.php?pagename=John_D._Rockefeller&params=41.511_N_81.591_W_type:landmark\\region:US-OH',
#  '/wiki/Standard_Oil_Company',
#  '/wiki/University_of_Chicago',
#  '/wiki/Rockefeller_University',
#  '/wiki/Central_Philippine_University',
#  '/wiki/General_Education_Board',
#  '/wiki/Rockefeller_Foundation',
#  '/wiki/Republican_Party_(United_States)',
#  '/wiki/Laura_Spelman_Rockefeller',
#  '/wiki/Elizabeth_Rockefeller_Strong',
#  '/wiki/Alta_Rockefeller_Prentice',
#  '/wiki/Edith_Rockefeller_McCormick',
#  '/wiki/John_D._Rockefeller_Jr.',
#  '/wiki/William_Rockefeller_Sr.',
#  '/wiki/Rockefeller_family',
#  '/wiki/List_of_richest_Americans_in_history',
#  '#cite_note-Fortune-1',
#  '#cite_note-2',
#  '/wiki/List_of_wealthiest_historical_figures',
#  '#cite_note-3',
#  '#cite_note-4',
#  '/wiki/Upstate_New_York',
#  '/wiki/Cleveland',
#  '/wiki/Bookkeeper',
#  '/wiki/Oil_refining',
#  '/wiki/Standard_Oil_Company',
#  '#cite_note-5',
#  '/wiki/Trust_(business)',
#  '/wiki/Ida_Tarbell',
#  '/wiki/Standard_Oil_Co._of_New_Jersey_v._United_States',
#  '/wiki/Antitrust_laws',
#  '/wiki/ExxonMobil',
#  '/wiki/Chevron_Corporation',
#  '/wiki/List_of_largest_companies_by_revenue',
#  '#cite_note-6',
#  '#cite_note-7',
#  '/wiki/Wikipedia:Citing_sources#What_information_to_include',
#  '#cite_note-8',
#  '/wiki/Wikipedia:Citing_sources',
#  '#cite_note-9',
#  '#cite_note-10',
#  '/wiki/Kykuit',
#  '/wiki/Westchester_County,_New_York',
#  '/wiki/Andrew_Carnegie',
#  '#cite_note-11',
#  '#cite_note-FOOTNOTEFosdick1989[[Category:Wikipedia_articles_needing_page_number_citations_from_February_2021]]<sup_class="noprint_Inline-Template_"_style="white-space:nowrap;">&#91;<i>[[Wikipedia:Citing_sources|<span_title="This_citation_requires_a_reference_to_the_specific_page_or_range_of_pages_in_which_the_material_appears.&#32;(February_2021)">page&nbsp;needed</span>]]</i>&#93;</sup>-12',
#  '/wiki/Hookworm',
#  '#cite_note-13',
#  '/wiki/Yellow_fever',
#  '#cite_note-14',
#  '/wiki/Abraham_Flexner',
#  '#cite_note-afjrg-15',
#  '/wiki/University_of_Chicago',
#  '/wiki/Rockefeller_University',
#  '/wiki/Central_Philippine_University',
#  '#cite_note-A_walk_through_the_beautiful_Central-16',
#  '#cite_note-Weekly_Centralian_Link_(June_15,_2018)_-_CPU_holds_Faculty_and_Staff_Conference_2018-17',
#  '#cite_note-Facts_about_Central-18',
#  '/wiki/American_Baptist_Churches_USA',
#  '#cite_note-19',
#  '/wiki/Laura_Spelman_Rockefeller',
#  '#cite_note-FOOTNOTEChernow199852-20',
#  '/wiki/Social_Darwinism',
#  '#cite_note-FOOTNOTEHofstadter199245-21',
#  '#cite_note-22',
#  '/wiki/File:John_D._Rockefeller%27s_birthplace_at_Richford,_New_York.jpg',
#  '/wiki/File:John_D._Rockefeller%27s_birthplace_at_Richford,_New_York.jpg',
#  '/wiki/Richford,_New_York',
#  '/wiki/William_Rockefeller_Sr.',
#  '/wiki/William_Rockefeller_Jr.',
#  '/wiki/Frank_Rockefeller',
#  '/wiki/Scotch-Irish_Americans',
#  '#cite_note-23',
#  '#cite_note-FOOTNOTEChernow199811-24',
#  '#cite_note-FOOTNOTEChernow19986-25',
#  '#cite_note-26',
#  '#cite_note-FOOTNOTEChernow199843-27',
#  '#cite_note-30',
#  '#cite_note-FOOTNOTESegall200114-31',
#  '#cite_note-FOOTNOTESegall200115–16-32',
#  '#cite_note-33',
#  '/wiki/Moravia_(village),_New_York',
#  '/wiki/Owego_(village),_New_York',
#  '/wiki/Strongsville,_Ohio',
#  '/wiki/Central_High_School_(Cleveland,_Ohio)',
#  '/wiki/Folsom%27s_Commercial_College',
#  '#cite_note-34',
#  '#cite_note-FOOTNOTEChernow199840-35',
#  '/wiki/File:John_D._Rockefeller_aged_18_-_Project_Gutenberg_eText_17090-crop.jpg',
#  '/wiki/File:John_D._Rockefeller_aged_18_-_Project_Gutenberg_eText_17090-crop.jpg',
#  '/wiki/Bookkeeper',
#  '#cite_note-36',
#  '#cite_note-FOOTNOTEChernow199846-37',
#  '#cite_note-FOOTNOTEHawke198023,_24-38',
#  '#cite_note-FOOTNOTEHawke198022-39',
#  '#cite_note-inflation-US-40',
#  '#cite_note-41',
#  '/wiki/Maurice_B._Clark',
#  '#cite_note-FOOTNOTEHawke198026-42',
#  '#cite_note-FOOTNOTESegall200125-43',
#  '/wiki/American_Civil_War',
#  '/wiki/Union_Army',
#  '#cite_note-FOOTNOTEHawke198029,_36-44',
#  '/wiki/Enrollment_Act#Substitution',
#  '/wiki/Abolitionist',
#  '/wiki/Abraham_Lincoln',
#  '/wiki/Republican_Party_(United_States)',
#  '#cite_note-FOOTNOTESegall200124–28-45',
#  '/wiki/Methodist',
#  '/wiki/John_Wesley',
#  '#cite_note-FOOTNOTEChernow199854–55-46',
#  '#cite_note-FOOTNOTEFolsom2003"Chapter_5:_John_D._Rockefeller_and_the_Oil_Industry"-47',
#  '#cite_note-FOOTNOTEWilliamsonDaum195982–194-48',
#  '#cite_note-FOOTNOTEHawke198031,_32-49',
#  '/wiki/Oil_refinery',
#  '/wiki/The_Flats',
#  '/wiki/Chemist',
#  '/wiki/Samuel_Andrews_(chemist)',
#  '/wiki/Whale_oil',
#  '#cite_note-FOOTNOTEChernow199873–74-50',
#  '#cite_note-FOOTNOTENevins1940183–185,_197–198-51',
#  '#cite_note-FOOTNOTEFolsom2003"Chapter_5:_John_D._Rockefeller_and_the_Oil_Industry"-47',
#  '/wiki/Wikipedia:Citation_needed',
#  '/wiki/Daniel_Yergin',
#  '#cite_note-inflation-US-40',
#  '#cite_note-FOOTNOTESegall200132-52',
#  '/wiki/Railroads',
#  '/wiki/Oil',
#  '#cite_note-FOOTNOTESegall200132,_35-53',
#  '/wiki/Henry_Morrison_Flagler',
#  '/wiki/Rockefeller,_Andrews_%26_Flagler',
#  '/wiki/New_York_City',
#  '#cite_note-54',
#  '#cite_note-55',
#  '/wiki/Wikipedia:Citation_needed',
#  '/wiki/Standard_Oil',
#  '/wiki/File:John_D_Rockefeller_1872.png',
#  '/wiki/File:John_D_Rockefeller_1872.png',
#  '/wiki/American_Civil_War',
#  '/wiki/Cleveland',
#  '/wiki/Pittsburgh,_Pennsylvania',
#  '/wiki/New_York_(state)',
#  '/wiki/Pennsylvania',
#  '#cite_note-FOOTNOTEYergin1991[[Category:Wikipedia_articles_needing_page_number_citations_from_February_2021]]<sup_class="noprint_Inline-Template_"_style="white-space:nowrap;">&#91;<i>[[Wikipedia:Citing_sources|<span_title="This_citation_requires_a_reference_to_the_specific_page_or_range_of_pages_in_which_the_material_appears.&#32;(February_2021)">page&nbsp;needed</span>]]</i>&#93;</sup>-56',
#  '#cite_note-FOOTNOTEChernow1998132-57',
#  '/wiki/Cartel',
#  '/wiki/South_Improvement_Company',
#  '#cite_note-FOOTNOTESegall200142-58',
#  '/wiki/File:John-D-Rockefeller-sen.jpg',
#  '/wiki/File:John-D-Rockefeller-sen.jpg',
#  '/wiki/File:Standard_Oil_Company_1878.JPG',
#  '/wiki/File:Standard_Oil_Company_1878.JPG',
#  '#cite_note-59',
#  '/wiki/Charles_Pratt_and_Company',
#  '/wiki/Charles_Pratt',
#  '/wiki/Henry_H._Rogers',
#  '#cite_note-FOOTNOTESegall200143-60',
#  '#cite_note-FOOTNOTENevins1940183–185,_197–198-51',
#  '#cite_note-FOOTNOTESegall200144-61',
#  '/wiki/Wikipedia:Citation_needed',
#  '/wiki/File:Standard_oil.OILSTOCK.JPG',
#  '/wiki/File:Standard_oil.OILSTOCK.JPG',
#  '/wiki/Charles_Millard_Pratt',
#  '#cite_note-FOOTNOTENevins1940183–185,_197–198-51',
#  '#cite_note-FOOTNOTESegall200146-62',
#  '/wiki/Horizontal_integration',
#  '/wiki/Vertical_integration',
#  '#cite_note-FOOTNOTESegall200148–49-63',
#  '#cite_note-inflation-US-40',
#  '#cite_note-FOOTNOTESegall200152-64',
#  '/wiki/Vertical_integration',
#  '#cite_note-FOOTNOTEYergin1991[[Category:Wikipedia_articles_needing_page_number_citations_from_February_2021]]<sup_class="noprint_Inline-Template_"_style="white-space:nowrap;">&#91;<i>[[Wikipedia:Citing_sources|<span_title="This_citation_requires_a_reference_to_the_specific_page_or_range_of_pages_in_which_the_material_appears.&#32;(February_2021)">page&nbsp;needed</span>]]</i>&#93;</sup>-56',
#  '/wiki/File:Standard_Oil.jpg',
#  '/wiki/File:Standard_Oil.jpg',
#  '/wiki/Thomas_A._Scott',
#  '/wiki/Pennsylvania_Railroad',
#  '#cite_note-FOOTNOTEChernow1998171-65',
#  '#cite_note-FOOTNOTESegall200157-66',
#  '#cite_note-FOOTNOTESegall200158-67',
#  '#cite_note-FOOTNOTEYergin1991[[Category:Wikipedia_articles_needing_page_number_citations_from_February_2021]]<sup_class="noprint_Inline-Template_"_style="white-space:nowrap;">&#91;<i>[[Wikipedia:Citing_sources|<span_title="This_citation_requires_a_reference_to_the_specific_page_or_range_of_pages_in_which_the_material_appears.&#32;(February_2021)">page&nbsp;needed</span>]]</i>&#93;</sup>-56',
#  '/wiki/File:Portrait_of_John_D_Rockefeller_by_Eastman_Johnson,_1895.jpg',
#  '/wiki/File:Portrait_of_John_D_Rockefeller_by_Eastman_Johnson,_1895.jpg',
#  '/wiki/Eastman_Johnson',
#  '/wiki/Horizontal_integration',
#  '#cite_note-FOOTNOTEFolsom2003"Chapter_5:_John_D._Rockefeller_and_the_Oil_Industry"-47',
#  '#cite_note-FOOTNOTEChernow1998253-68',
#  '#cite_note-FOOTNOTEChernow1998258-69',
#  '/wiki/Monopoly',
#  '/wiki/Antitrust',
#  '/wiki/New_York_State_Legislature',
#  '/wiki/The_Hepburn_Committee',
#  '#cite_note-70',
#  '/wiki/New_York_World',
#  '#cite_note-FOOTNOTESegall200160-71',
#  '#cite_note-72',
#  '/wiki/Trust_(business)',
#  '#cite_note-FOOTNOTESegall200161-73',
#  '#cite_note-FOOTNOTEChernow1998249-74',
#  '/wiki/File:William_McKinley_Campagne.jpg',
#  '/wiki/File:William_McKinley_Campagne.jpg',
#  '/wiki/William_McKinley_1896_presidential_campaign',
#  '#cite_note-FOOTNOTEChernow1998249-74',
#  '#cite_note-FOOTNOTESegall200167-75',
#  '#cite_note-FOOTNOTESegall200167-75',
#  '/wiki/National_Petroleum_Exchange',
#  '#cite_note-FOOTNOTEChernow1998259-76',
#  '#cite_note-FOOTNOTEChernow1998242-77',
#  '/wiki/Robert_Nobel',
#  '/wiki/Rothschild_banking_family_of_France',
#  '#cite_note-FOOTNOTEChernow1998246-78',
#  '/wiki/Natural_gas',
#  '#cite_note-FOOTNOTESegall200168-79',
#  '/wiki/File:Standard_oil_octopus_loc_color.jpg',
#  '/wiki/File:Standard_oil_octopus_loc_color.jpg',
#  '/wiki/William_Henry_Vanderbilt',
#  '#cite_note-FOOTNOTESegall200162–63-80',
#  '/wiki/Interstate_Commerce_Commission',
#  '#cite_note-FOOTNOTERockefeller198448-81',
#  '/wiki/Sherman_Antitrust_Act',
#  '#cite_note-FOOTNOTESegall200169-82',
#  '/wiki/File:Jdr-king.JPG',
#  '/wiki/File:Jdr-king.JPG',
#  '/wiki/Puck_(magazine)',
#  '/wiki/Andrew_Carnegie',
#  '#cite_note-FOOTNOTESegall200177-83',
#  '#cite_note-FOOTNOTEChernow1998287-84',
#  '/wiki/John_Dustin_Archbold',
#  '/wiki/Kykuit#Pocantico,_the_family_estate',
#  '#cite_note-FOOTNOTESegall200179–80-85',
#  '/wiki/File:PuckCartoon-TeddyRoosevelt-05-23-1906.jpg',
#  '/wiki/File:PuckCartoon-TeddyRoosevelt-05-23-1906.jpg',
#  '/wiki/Theodore_Roosevelt',
#  '/wiki/Nelson_W._Aldrich',
#  '/wiki/U.S._Steel',
#  '/wiki/J._Pierpont_Morgan',
#  '/wiki/Henry_Clay_Frick',
#  '#cite_note-FOOTNOTESegall200184-86',
#  '/wiki/The_History_of_the_Standard_Oil_Company',
#  '/wiki/Ida_Tarbell',
#  '/wiki/Muckraker',
#  '#cite_note-FOOTNOTESegall200189-87',
#  '/wiki/South_Improvement_Company',
#  '/wiki/Wikipedia:Citation_needed',
#  '#cite_note-FOOTNOTESegall200189-87',
#  '#cite_note-FOOTNOTESegall200191-88',
#  '/wiki/File:Landis_Rockefeller_1.png',
#  '/wiki/File:Landis_Rockefeller_1.png',
#  '/wiki/Kenesaw_Mountain_Landis',
#  '/wiki/Holding_company',
#  '/wiki/Supreme_Court_of_the_United_States',
#  '/wiki/Standard_Oil_Company_of_New_Jersey',
#  '/wiki/Sherman_Antitrust_Act',
#  '#cite_note-FOOTNOTESegall200193-89',
#  '/wiki/Monopoly',
#  '/wiki/Conoco',
#  '/wiki/ConocoPhillips',
#  '/wiki/Amoco',
#  '/wiki/BP',
#  '/wiki/Chevron_Corporation',
#  '/wiki/Esso',
#  '/wiki/Exxon',
#  '/wiki/ExxonMobil',
#  '/wiki/Mobil',
#  '/wiki/Sohio',
#  '/wiki/Pennzoil',
#  '#cite_note-FOOTNOTESegall2001112-90',
#  '/wiki/File:John_D._Rockefeller,_Sr.jpg',
#  '/wiki/File:John_D._Rockefeller,_Sr.jpg',
#  '/wiki/Alopecia',
#  '#cite_note-FOOTNOTEChernow1998333-91',
#  '#cite_note-FOOTNOTESegall200193-89',
#  '/wiki/John_C._Osgood',
#  '/wiki/George_Jay_Gould_I',
#  '#cite_note-FOOTNOTEScamehorn1992a17-92',
#  '/wiki/Frederick_Taylor_Gates',
#  '#cite_note-FOOTNOTEScamehorn1992a18-93',
#  '#cite_note-FOOTNOTEScamehorn1992a19-94',
#  '#cite_note-FOOTNOTEScamehorn1992a20-95',
#  '/wiki/Ludlow_Massacre',
#  '/wiki/Collective_bargaining',
#  '#cite_note-Lamont-Montgomery-Bowers-96',
#  '/wiki/Strikebreakers',
#  '/wiki/Tent_city',
#  '/wiki/Trinidad,_Colorado',
#  '#cite_note-FOOTNOTEScamehorn1992c-97',
#  '#cite_note-FOOTNOTEScamehorn1992c-97',
#  '#cite_note-history-1914-ludlow-98',
#  '/wiki/Rockefeller_Foundation',
#  '#cite_note-FOOTNOTEScamehorn1992c-97',
#  '/wiki/Commission_on_Industrial_Relations',
#  '#cite_note-FOOTNOTEScamehorn1992c-97',
#  '#cite_note-pbs-99',
#  '/wiki/Ludlow_Massacre',
#  '#cite_note-newyorktimes-21may1915-100',
#  '/wiki/Rockefeller_family',
#  '/wiki/Protestant',
#  '/wiki/Rengsdorf',
#  '/wiki/Neuwied',
#  '/wiki/Rhineland-Palatinate',
#  '/wiki/Germantown,_Philadelphia',
#  '#cite_note-FOOTNOTEChernow19983,_10-101',
#  '#cite_note-102',
#  '/wiki/Rockenfeld',
#  '/wiki/Neuwied_(district)',
#  '/wiki/Wikipedia:Citation_needed',
#  '/wiki/File:Kykuit,_Tarrytown,_NY_-_front_facade.JPG',
#  '/wiki/File:Kykuit,_Tarrytown,_NY_-_front_facade.JPG',
#  '/wiki/Kykuit',
#  '/wiki/Laura_Spelman_Rockefeller',
#  '#cite_note-FOOTNOTESegall200125-43',
#  '/wiki/Elizabeth_Rockefeller_Strong',
#  '/wiki/Alta_Rockefeller_Prentice',
#  '/wiki/Edith_Rockefeller_McCormick',
#  '/wiki/John_D._Rockefeller_Jr.',
#  '/wiki/David_Rockefeller',
#  '/wiki/Chase_(bank)',
#  '/wiki/JPMorgan_Chase',
#  '/wiki/Nelson_Rockefeller',
#  '/wiki/Vice_President_of_the_United_States',
#  '/wiki/Winthrop_Rockefeller',
#  '/wiki/Governor_of_Arkansas',
#  '/wiki/Abby_Rockefeller_Mauz%C3%A9',
#  '/wiki/John_D._Rockefeller_III',
#  '/wiki/Laurance_Rockefeller',
#  '/wiki/Jay_Rockefeller',
#  '/wiki/Democratic_Party_(United_States)',
#  '/wiki/List_of_United_States_Senators_from_West_Virginia',
#  '#cite_note-103',
#  '/wiki/Winthrop_Paul_Rockefeller',
#  '/wiki/File:Euclid_Avenue_Baptist_Church_and_Charles_Aubrey_Eaton,_pastor.jpg',
#  '/wiki/File:Euclid_Avenue_Baptist_Church_and_Charles_Aubrey_Eaton,_pastor.jpg',
#  '/wiki/Richford,_New_York',
#  '/wiki/Burned-over_district',
#  '/wiki/Evangelical',
#  '/wiki/Christian_revival',
#  '/wiki/Second_Great_Awakening',
#  '/wiki/Protestant',
#  '/wiki/Northern_Baptist_Convention',
#  '/wiki/American_Baptist_Churches_USA',
#  '/wiki/Wikipedia:Citation_needed',
#  '#cite_note-Rockefellers_documentary-104',
#  '#cite_note-Rockefellers_documentary-104',
#  '#cite_note-Rockefellers_documentary-104',
#  '/wiki/Cleveland,_Ohio',
#  '/wiki/American_South',
#  '/wiki/Southern_Baptist_Convention',
#  '/wiki/Black_churches',
#  '#cite_note-FOOTNOTESegall200124-105',
#  '/wiki/Roman_Catholic',
#  '#cite_note-Rockefellers_documentary-104',
#  '/wiki/File:John_D._Rockefeller.jpg',
#  '/wiki/File:John_D._Rockefeller.jpg',
#  '#cite_note-FOOTNOTEChernow199850,_235-29',
#  '/wiki/American_Baptist_Churches_USA',
#  '/wiki/American_Baptist_Home_Mission_Society',
#  '/wiki/Freedmen',
#  '/wiki/Southern_United_States',
#  '/wiki/American_Civil_War',
#  '#cite_note-FOOTNOTEChernow199850,_235-29',
#  '/wiki/Frederick_Taylor_Gates',
#  '#cite_note-106',
#  '#cite_note-107',
#  '/wiki/File:Rockefellers.png',
#  '/wiki/File:Rockefellers.png',
#  '/wiki/John_D._Rockefeller,_Jr.',
#  '/wiki/Efficiency_Movement',
#  '#cite_note-FOOTNOTERockefeller198469-108',
#  '#cite_note-FOOTNOTERockefeller1984183-109',
#  '/wiki/Spelman_College',
#  '#cite_note-Weir-110',
#  '#cite_note-Laughlin,_Rosemary_2001-111',
#  '/wiki/Historically_black_colleges_and_universities',
#  '#cite_note-Laughlin,_Rosemary_2001-111',
#  '#cite_note-112',
#  '/wiki/Denison_University',
#  '#cite_note-FOOTNOTEFosdick19895,_88-113',
#  '/wiki/File:Harper_Midway_Chicago.jpg',
#  '/wiki/File:Harper_Midway_Chicago.jpg',
#  '/wiki/Midway_Plaisance',
#  '/wiki/File:Central_Philippine_University_Church.JPG',
#  '/wiki/File:Central_Philippine_University_Church.JPG',
#  '/wiki/Central_Philippine_University',
#  '/wiki/Iloilo_City',
#  '/wiki/University_of_Chicago',
#  '#cite_note-114',
#  '/wiki/William_Rainey_Harper',
#  '/wiki/American_Baptist_Foreign_Mission_Society',
#  '/wiki/Central_Philippine_University',
#  '/wiki/Baptist',
#  '/wiki/United_States',
#  '/wiki/Asia',
#  '/wiki/Philippines',
#  '#cite_note-115',
#  '#cite_note-116',
#  '#cite_note-Facts_about_Central-18',
#  '#cite_note-A_walk_through_the_beautiful_Central-16',
#  '#cite_note-Weekly_Centralian_Link_(June_15,_2018)_-_CPU_holds_Faculty_and_Staff_Conference_2018-17',
#  '/wiki/General_Education_Board',
#  '#cite_note-Brison-117',
#  '#cite_note-Jones-Wilson-118',
#  '#cite_note-Jones-Wilson-118',
#  '/wiki/Yale',
#  '/wiki/Harvard',
#  '/wiki/Columbia_University',
#  '/wiki/Brown_University',
#  '/wiki/Bryn_Mawr_College',
#  '/wiki/Wellesley_College',
#  '/wiki/Vassar_College',
#  '/wiki/Medical_science',
#  '#cite_note-Brison-117',
#  '/wiki/Rockefeller_University',
#  '#cite_note-119',
#  '#cite_note-120',
#  '#cite_note-Brison-117',
#  '/wiki/Hookworm',
#  '#cite_note-121',
#  '/wiki/American_South',
#  '/wiki/Flexner_Report',
#  '/wiki/Wikipedia:Citation_needed',
#  '/wiki/The_Atlantic',
#  '#cite_note-afjrg-15',
#  '/wiki/Carnegie_Foundation_for_the_Advancement_of_Teaching',
#  '/wiki/Wikipedia:Citation_needed',
#  '/wiki/File:PSM_V80_D416_Rockefeller_institute_for_medical_research.png',
#  '/wiki/File:PSM_V80_D416_Rockefeller_institute_for_medical_research.png',
#  '/wiki/New_York_City',
#  '/wiki/Rockefeller_Foundation',
#  '#cite_note-FOOTNOTEKlein2005143-122',
#  '#cite_note-Brison-117',
#  '#cite_note-123',
#  '#cite_note-Weir-110',
#  '/wiki/Johns_Hopkins_Bloomberg_School_of_Public_Health',
#  '#cite_note-Brison-117',
#  '#cite_note-124',
#  '/wiki/Peking_Union_Medical_College',
#  '#cite_note-FOOTNOTEFosdick19895,_88-113',
#  '/wiki/World_War_I',
#  '#cite_note-125',
#  '/wiki/William_Lyon_Mackenzie_King',
#  '#cite_note-126',
#  '/wiki/International_Health_Division',
#  '#cite_note-127',
#  '#cite_note-128',
#  '#cite_note-129',
#  '/wiki/File:John_D._Rockefeller_in_old_age.jpg',
#  '/wiki/File:John_D._Rockefeller_in_old_age.jpg',
#  '/wiki/Business_magnate',
#  '/wiki/Harvey_Firestone',
#  '#cite_note-FOOTNOTEChernow1998613–14-130',
#  '/wiki/Eighteenth_Amendment_to_the_United_States_Constitution',
#  '/wiki/Nicholas_Murray_Butler',
#  '/wiki/Anti-Saloon_League',
#  '#cite_note-131',
#  '/wiki/File:Ormond_Beach_Casements03.jpg',
#  '/wiki/File:Ormond_Beach_Casements03.jpg',
#  '/wiki/Henry_Flagler',
#  '/wiki/Ormond_Beach,_Florida',
#  '/wiki/Florida_East_Coast_Railway',
#  '/wiki/The_Casements',
#  '#cite_note-FOOTNOTEStasz2000209-132',
#  '#cite_note-FOOTNOTEChernow1998610-133',
#  '#cite_note-134',
#  '#cite_note-135',
#  '/wiki/File:Rockefeller,_John_D,_1922,_Agence_Rol,_BNF_Gallica_(cropped).jpg',
#  '/wiki/File:Rockefeller,_John_D,_1922,_Agence_Rol,_BNF_Gallica_(cropped).jpg',
#  '/wiki/Clinical_depression',
#  '/wiki/Alopecia',
#  '#cite_note-136',
#  '/wiki/Toup%C3%A9e',
#  '#cite_note-137',
#  '/wiki/File:Rockefeller_grave_2.JPG',
#  '/wiki/File:Rockefeller_grave_2.JPG',
#  '/wiki/Arteriosclerosis',
#  '#cite_note-138',
#  '/wiki/The_Casements',
#  '/wiki/Ormond_Beach,_Florida',
#  '/wiki/Lake_View_Cemetery',
#  '#cite_note-139',
#  'https://www.c-span.org/video/?105430-1/titan-life-john-d-rockefeller-sr',
#  '/wiki/C-SPAN',
#  '/wiki/File:John_D._Rockefeller_1917_painting.jpg',
#  '/wiki/File:John_D._Rockefeller_1917_painting.jpg',
#  '/wiki/John_Singer_Sargent',
#  '/wiki/Amalgamation_(fiction)',
#  '/wiki/Robber_baron_(industrialist)',
#  '/wiki/Allan_Nevins',
#  '/wiki/Andrew_Carnegie',
#  '#cite_note-FOOTNOTELatham1949104-140',
#  '#cite_note-141',
#  '/wiki/Ron_Chernow',
#  '#cite_note-142',
#  '#cite_note-FOOTNOTEChernow1998-143',
#  '/wiki/File:Rockefeller_golfing_(Jlustracja_Polska_1932.11.06_R.5_Nr45).jpg',
#  '/wiki/File:Rockefeller_golfing_(Jlustracja_Polska_1932.11.06_R.5_Nr45).jpg',
#  '/wiki/Gross_domestic_product',
#  '#cite_note-measuringworth.org-144',
#  '/wiki/World_War_I',
#  '#cite_note-145',
#  '/wiki/New_York_Times',
#  '#cite_note-146',
#  '#cite_note-Fortune-1',
#  '/wiki/Bill_Gates',
#  '/wiki/Sam_Walton',
#  '/wiki/Wikipedia:Citation_needed',
#  '#cite_note-147',
#  '/wiki/Allegheny_Transportation_Company',
#  '/wiki/Duluth,_Missabe_and_Northern_Railway',
#  '/wiki/Ivy_Lee',
#  '/wiki/List_of_German_Americans',
#  "/wiki/Mesabi_Range#Rockefellers'_Interests",
#  '#cite_ref-5',
#  '#cite_note-Fortune-1',
#  '#cite_ref-10',
#  '#cite_ref-30',
#  '/wiki/Joseph_Pulitzer',
#  '#cite_note-28',
#  '/wiki/Norwich,_Ontario',
#  '#cite_note-FOOTNOTEChernow199850,_235-29',
#  '#cite_ref-Fortune_1-0',
#  '#cite_ref-Fortune_1-1',
#  '#cite_ref-Fortune_1-2',
#  'https://money.cnn.com/gallery/luxury/2014/06/01/richest-americans-in-history',
#  '/wiki/Fortune_(magazine)',
#  '#cite_ref-2',
#  'https://www.nytimes.com/ref/business/20070715_GILDED_GRAPHIC.html',
#  '#cite_ref-3',
#  'http://www.askmen.com/toys/top_10/11b_top_10_list.html',
#  '/wiki/AskMen.com',
#  '#cite_ref-4',
#  'https://web.archive.org/web/20120126052525/http://www.pbs.org/wgbh/amex/rockefellers/filmmore/pt.html',
#  '/wiki/Public_Broadcasting_Service',
#  'https://www.pbs.org/wgbh/amex/rockefellers/filmmore/pt.html',
#  '#cite_ref-6',
#  'https://www.hbs.edu/faculty/Pages/item.aspx?num=47167',
#  '#cite_ref-7',
#  'http://www.usstuckonstupid.com/sos_charts.php#gdp',
#  'https://web.archive.org/web/20210602212500/http://www.usstuckonstupid.com/sos_charts.php#gdp',
#  '/wiki/Wayback_Machine',
#  '#cite_ref-8',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/9780874700312',
#  '#cite_ref-9',
#  'http://www.fbacs.com/?p=2063&lang=en',
#  '#cite_ref-11',
#  'https://www.nytimes.com/2006/07/02/business/yourmoney/02view.html',
#  '/wiki/The_New_York_Times',
#  '#cite_ref-FOOTNOTEFosdick1989[[Category:Wikipedia_articles_needing_page_number_citations_from_February_2021]]<sup_class="noprint_Inline-Template_"_style="white-space:nowrap;">&#91;<i>[[Wikipedia:Citing_sources|<span_title="This_citation_requires_a_reference_to_the_specific_page_or_range_of_pages_in_which_the_material_appears.&#32;(February_2021)">page&nbsp;needed</span>]]</i>&#93;</sup>_12-0',
#  '#CITEREFFosdick1989',
#  '/wiki/Wikipedia:Citing_sources',
#  '#cite_ref-13',
#  'https://web.archive.org/web/20170223174919/http://www.rockefeller100.org/exhibits/show/health/eradicating-hookworm',
#  'http://www.rockefeller100.org/exhibits/show/health/eradicating-hookworm',
#  '#cite_ref-14',
#  'https://web.archive.org/web/20170320010541/http://www.rockefeller100.org/exhibits/show/health/eradicating-hookworm/hookworm-exporting-a-campaign',
#  'http://rockefeller100.org/exhibits/show/health/eradicating-hookworm/hookworm-exporting-a-campaign',
#  '#cite_ref-afjrg_15-0',
#  '#cite_ref-afjrg_15-1',
#  'https://www.theatlantic.com/health/archive/2011/06/the-man-who-invented-medical-school/240887/',
#  '#cite_ref-A_walk_through_the_beautiful_Central_16-0',
#  '#cite_ref-A_walk_through_the_beautiful_Central_16-1',
#  'https://cpu.edu.ph/weekly-centralian-link-december-8-2017/',
#  '#cite_ref-Weekly_Centralian_Link_(June_15,_2018)_-_CPU_holds_Faculty_and_Staff_Conference_2018_17-0',
#  '#cite_ref-Weekly_Centralian_Link_(June_15,_2018)_-_CPU_holds_Faculty_and_Staff_Conference_2018_17-1',
#  'https://cpu.edu.ph/weekly-centralian-link-june-15-2018/',
#  '#cite_ref-Facts_about_Central_18-0',
#  '#cite_ref-Facts_about_Central_18-1',
#  'https://cpu.edu.ph/news/facts-about-central/',
#  '#cite_ref-19',
#  '/wiki/Encyclopedia_Americana',
#  '#cite_ref-FOOTNOTEChernow199852_20-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-FOOTNOTEHofstadter199245_21-0',
#  '#CITEREFHofstadter1992',
#  '#cite_ref-22',
#  '#cite_ref-23',
#  '#CITEREFChernow1998',
#  'https://archive.org/details/titan00ronc_0/page/7',
#  '#cite_ref-FOOTNOTEChernow199811_24-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-FOOTNOTEChernow19986_25-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-26',
#  '#CITEREFChernow1998',
#  'https://www.nytimes.com/books/first/c/chernow-titan.html',
#  '#cite_ref-FOOTNOTEChernow199843_27-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-28',
#  '/wiki/John_T._Flynn',
#  'https://www.mises.org/books/gold.pdf',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-0-837-15588-3',
#  '#cite_ref-FOOTNOTEChernow199850,_235_29-0',
#  '#cite_ref-FOOTNOTEChernow199850,_235_29-1',
#  '#cite_ref-FOOTNOTEChernow199850,_235_29-2',
#  '#CITEREFChernow1998',
#  '#cite_ref-FOOTNOTESegall200114_31-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTESegall200115–16_32-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-33',
#  'http://www.challies.com/articles/the-philanthropists-john-d-rockefeller',
#  '#cite_ref-34',
#  '#cite_ref-FOOTNOTEChernow199840_35-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-36',
#  'https://www.britannica.com/biography/John-D-Rockefeller',
#  '#cite_ref-FOOTNOTEChernow199846_37-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-FOOTNOTEHawke198023,_24_38-0',
#  '#CITEREFHawke1980',
#  '#cite_ref-FOOTNOTEHawke198022_39-0',
#  '#CITEREFHawke1980',
#  '#cite_ref-inflation-US_40-0',
#  '#cite_ref-inflation-US_40-1',
#  '#cite_ref-inflation-US_40-2',
#  'https://www.americanantiquarian.org/proceedings/44525121.pdf',
#  '/wiki/American_Antiquarian_Society',
#  'https://www.americanantiquarian.org/proceedings/44517778.pdf',
#  '/wiki/American_Antiquarian_Society',
#  'https://www.minneapolisfed.org/about-us/monetary-policy/inflation-calculator/consumer-price-index-1800-',
#  '#cite_ref-41',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-0-470-25287-1',
#  '#cite_ref-FOOTNOTEHawke198026_42-0',
#  '#CITEREFHawke1980',
#  '#cite_ref-FOOTNOTESegall200125_43-0',
#  '#cite_ref-FOOTNOTESegall200125_43-1',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTEHawke198029,_36_44-0',
#  '#CITEREFHawke1980',
#  '#cite_ref-FOOTNOTESegall200124–28_45-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTEChernow199854–55_46-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-FOOTNOTEFolsom2003"Chapter_5:_John_D._Rockefeller_and_the_Oil_Industry"_47-0',
#  '#cite_ref-FOOTNOTEFolsom2003"Chapter_5:_John_D._Rockefeller_and_the_Oil_Industry"_47-1',
#  '#cite_ref-FOOTNOTEFolsom2003"Chapter_5:_John_D._Rockefeller_and_the_Oil_Industry"_47-2',
#  '#CITEREFFolsom2003',
#  '#cite_ref-FOOTNOTEWilliamsonDaum195982–194_48-0',
#  '#CITEREFWilliamsonDaum1959',
#  '#cite_ref-FOOTNOTEHawke198031,_32_49-0',
#  '#CITEREFHawke1980',
#  '#cite_ref-FOOTNOTEChernow199873–74_50-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-FOOTNOTENevins1940183–185,_197–198_51-0',
#  '#cite_ref-FOOTNOTENevins1940183–185,_197–198_51-1',
#  '#cite_ref-FOOTNOTENevins1940183–185,_197–198_51-2',
#  '#CITEREFNevins1940',
#  '#cite_ref-FOOTNOTESegall200132_52-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTESegall200132,_35_53-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-54',
#  'https://web.archive.org/web/20001216230400/https://www.pbs.org/wgbh/amex/rockefellers/peopleevents/p_rock_jsr.html',
#  'https://www.pbs.org/wgbh/amex/rockefellers/peopleevents/p_rock_jsr.html',
#  '#cite_ref-55',
#  'https://web.archive.org/web/20081112123409/http://www.exxonmobil.com/Corporate/history/about_who_history.aspx',
#  'http://www.exxonmobil.com/Corporate/history/about_who_history.aspx',
#  '#cite_ref-FOOTNOTEYergin1991[[Category:Wikipedia_articles_needing_page_number_citations_from_February_2021]]<sup_class="noprint_Inline-Template_"_style="white-space:nowrap;">&#91;<i>[[Wikipedia:Citing_sources|<span_title="This_citation_requires_a_reference_to_the_specific_page_or_range_of_pages_in_which_the_material_appears.&#32;(February_2021)">page&nbsp;needed</span>]]</i>&#93;</sup>_56-0',
#  '#cite_ref-FOOTNOTEYergin1991[[Category:Wikipedia_articles_needing_page_number_citations_from_February_2021]]<sup_class="noprint_Inline-Template_"_style="white-space:nowrap;">&#91;<i>[[Wikipedia:Citing_sources|<span_title="This_citation_requires_a_reference_to_the_specific_page_or_range_of_pages_in_which_the_material_appears.&#32;(February_2021)">page&nbsp;needed</span>]]</i>&#93;</sup>_56-1',
#  '#cite_ref-FOOTNOTEYergin1991[[Category:Wikipedia_articles_needing_page_number_citations_from_February_2021]]<sup_class="noprint_Inline-Template_"_style="white-space:nowrap;">&#91;<i>[[Wikipedia:Citing_sources|<span_title="This_citation_requires_a_reference_to_the_specific_page_or_range_of_pages_in_which_the_material_appears.&#32;(February_2021)">page&nbsp;needed</span>]]</i>&#93;</sup>_56-2',
#  '#CITEREFYergin1991',
#  '/wiki/Wikipedia:Citing_sources',
#  '#cite_ref-FOOTNOTEChernow1998132_57-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-FOOTNOTESegall200142_58-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-59',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/3921722063',
#  '#cite_ref-FOOTNOTESegall200143_60-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTESegall200144_61-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTESegall200146_62-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTESegall200148–49_63-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTESegall200152_64-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTEChernow1998171_65-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-FOOTNOTESegall200157_66-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTESegall200158_67-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTEChernow1998253_68-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-FOOTNOTEChernow1998258_69-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-70',
#  'https://archive.org/details/cu31924022800019/page/n5/mode/2up?view=theater',
#  '#cite_ref-FOOTNOTESegall200160_71-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-72',
#  'http://www.history.com/topics/john-d-rockefeller',
#  '#cite_ref-FOOTNOTESegall200161_73-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTEChernow1998249_74-0',
#  '#cite_ref-FOOTNOTEChernow1998249_74-1',
#  '#CITEREFChernow1998',
#  '#cite_ref-FOOTNOTESegall200167_75-0',
#  '#cite_ref-FOOTNOTESegall200167_75-1',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTEChernow1998259_76-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-FOOTNOTEChernow1998242_77-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-FOOTNOTEChernow1998246_78-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-FOOTNOTESegall200168_79-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTESegall200162–63_80-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTERockefeller198448_81-0',
#  '#CITEREFRockefeller1984',
#  '#cite_ref-FOOTNOTESegall200169_82-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTESegall200177_83-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTEChernow1998287_84-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-FOOTNOTESegall200179–80_85-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTESegall200184_86-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTESegall200189_87-0',
#  '#cite_ref-FOOTNOTESegall200189_87-1',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTESegall200191_88-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTESegall200193_89-0',
#  '#cite_ref-FOOTNOTESegall200193_89-1',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTESegall2001112_90-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-FOOTNOTEChernow1998333_91-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-FOOTNOTEScamehorn1992a17_92-0',
#  '#CITEREFScamehorn1992a',
#  '#cite_ref-FOOTNOTEScamehorn1992a18_93-0',
#  '#CITEREFScamehorn1992a',
#  '#cite_ref-FOOTNOTEScamehorn1992a19_94-0',
#  '#CITEREFScamehorn1992a',
#  '#cite_ref-FOOTNOTEScamehorn1992a20_95-0',
#  '#CITEREFScamehorn1992a',
#  '#cite_ref-Lamont-Montgomery-Bowers_96-0',
#  'http://www.pressconnects.com/story/news/connections/history/2015/12/17/bowers-worked-rockefeller-left-legacy-broome/77489146/',
#  '#cite_ref-FOOTNOTEScamehorn1992c_97-0',
#  '#cite_ref-FOOTNOTEScamehorn1992c_97-1',
#  '#cite_ref-FOOTNOTEScamehorn1992c_97-2',
#  '#cite_ref-FOOTNOTEScamehorn1992c_97-3',
#  '#CITEREFScamehorn1992c',
#  '#cite_ref-history-1914-ludlow_98-0',
#  'http://www.history.com/this-day-in-history/militia-slaughters-strikers-at-ludlow-colorado',
#  '#cite_ref-pbs_99-0',
#  'https://www.pbs.org/wgbh/americanexperience/features/primary-resources/rockefellers-ludlow',
#  '/wiki/PBS',
#  '#cite_ref-newyorktimes-21may1915_100-0',
#  'http://historymatters.gmu.edu/d/5735',
#  '/wiki/The_New_York_Times',
#  '#cite_ref-FOOTNOTEChernow19983,_10_101-0',
#  '#CITEREFChernow1998',
#  '#cite_ref-102',
#  '#cite_ref-103',
#  'http://bioguide.congress.gov/scripts/biodisplay.pl?index=r000361',
#  '#cite_ref-Rockefellers_documentary_104-0',
#  '#cite_ref-Rockefellers_documentary_104-1',
#  '#cite_ref-Rockefellers_documentary_104-2',
#  '#cite_ref-Rockefellers_documentary_104-3',
#  '/wiki/Wikipedia:Citing_sources#What_information_to_include',
#  '#cite_ref-FOOTNOTESegall200124_105-0',
#  '#CITEREFSegall2001',
#  '#cite_ref-106',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/0-88738-334-3',
#  '#cite_ref-107',
#  'https://archive.org/details/isbn_9780226120263/page/42',
#  'https://archive.org/details/isbn_9780226120263/page/42',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/0-226-12025-2',
#  '#cite_ref-FOOTNOTERockefeller198469_108-0',
#  '#CITEREFRockefeller1984',
#  '#cite_ref-FOOTNOTERockefeller1984183_109-0',
#  '#CITEREFRockefeller1984',
#  '#cite_ref-Weir_110-0',
#  '#cite_ref-Weir_110-1',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-0-313-34245-5',
#  '#cite_ref-Laughlin,_Rosemary_2001_111-0',
#  '#cite_ref-Laughlin,_Rosemary_2001_111-1',
#  '#cite_ref-112',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/0-8265-1542-8',
#  '#cite_ref-FOOTNOTEFosdick19895,_88_113-0',
#  '#cite_ref-FOOTNOTEFosdick19895,_88_113-1',
#  '#CITEREFFosdick1989',
#  '#cite_ref-114',
#  '/wiki/Byron_Dobell',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/0-8281-1175-8',
#  '#cite_ref-115',
#  'https://web.archive.org/web/20031031061637/http://www.cpu.edu.ph/centennial/echo/no_1/page12.htm',
#  'http://www.cpu.edu.ph/centennial/echo/no_1/page12.htm',
#  '#cite_ref-116',
#  'https://web.archive.org/web/20110722233117/http://www.cpu.edu.ph/infocen/October05.htm',
#  'http://www.cpu.edu.ph/infocen/October05.htm',
#  '#cite_ref-Brison_117-0',
#  '#cite_ref-Brison_117-1',
#  '#cite_ref-Brison_117-2',
#  '#cite_ref-Brison_117-3',
#  '#cite_ref-Brison_117-4',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/0-7735-2868-7',
#  '#cite_ref-Jones-Wilson_118-0',
#  '#cite_ref-Jones-Wilson_118-1',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/0-313-28931-X',
#  '#cite_ref-119',
#  '/wiki/Harlow_Unger',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-0-8160-6887-6',
#  '#cite_ref-120',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-1-86470-295-8',
#  '#cite_ref-121',
#  '/wiki/Peter_Hotez',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/978-1-55581-440-3',
#  '#cite_ref-FOOTNOTEKlein2005143_122-0',
#  '#CITEREFKlein2005',
#  '#cite_ref-123',
#  '/wiki/Judith_Sealander',
#  'https://archive.org/details/isbn_9780801854606/page/58',
#  'https://archive.org/details/isbn_9780801854606/page/58',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/0-8018-5460-1',
#  '#cite_ref-124',
#  '#cite_ref-125',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/0-253-34151-5',
#  '#cite_ref-126',
#  '/wiki/Kenneth_Prewitt',
#  '/wiki/ISBN_(identifier)',
#  '/wiki/Special:BookSources/0-87154-696-5',
#  '#cite_ref-127',
#  '/wiki/Doi_(identifier)',
#  'https://doi.org/10.1016%2FS0277-9536%2899%2900160-4',
#  '/wiki/PMID_(identifier)',
#  'https://pubmed.ncbi.nlm.nih.gov/10501641',
#  '#cite_ref-128',
#  'https://web.archive.org/web/20111006092845/http://www.xtimeline.com/evt/view.aspx?id=50560',
#  'http://www.xtimeline.com/evt/view.aspx?id=50560',
#  ...]

# %% [markdown]
# # Comparison to other libraries

# %% [markdown]
# Parse 1000 html pages and find all links for each page.

# %%
def bsoup_default(all_html):
    """Beautiful Soup with html.parser parser"""
    for html in all_html:
        soup = BeautifulSoup(html, "html.parser")
        [link["href"] for link in soup.find_all("a", href=True)]


def bsoup_lxml(all_html):
    """Beautiful Soup with lxml parser
    pip install lxml
    """
    for html in all_html:
        soup = BeautifulSoup(html, "lxml")
        [link["href"] for link in soup.find_all("a", href=True)]


def selectolax_default(all_html):
    """Selectolax using Modest Engine"""
    for html in all_html:
        tree = HTMLParser(html)
        [node.attrs["href"] for node in tree.css("a[href]")]


def selectolax_lexbor(all_html):
    """Selectolax using lexbor Engine"""
    for html in all_html:
        tree = LexborHTMLParser(html)
        [node.attrs["href"] for node in tree.css("a[href]")]


def parsel_default(all_html):
    for html in all_html:
        selector = Selector(html)
        selector.css("a[href]::attr(href)").getall()


def load_all_files():
    """There are about 5000 random webpages saved in files
    files is gitignored"""
    all_html = []
    files = Path("files").iterdir()
    for file_path in files:
        with open(file_path, "r") as f:
            all_html.append(f.read())
    return all_html

# %%
all_html = load_all_files()

# %%
# %%time
bsoup_default(all_html)
# Out:
# CPU times: user 18.4 s, sys: 9.85 ms, total: 18.4 s
# Wall time: 18.4 s

# %%
# %%time
bsoup_lxml(all_html)
# Out:
# /home/calvin/github/CLEpy-MotM/Selectolax/.venv/lib/python3.10/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# CPU times: user 13.7 s, sys: 19.9 ms, total: 13.8 s
# Wall time: 13.8 s

# %%
# %%time
parsel_default(all_html)
# Out:
# CPU times: user 1.78 s, sys: 8 µs, total: 1.78 s
# Wall time: 1.77 s

# %%
# %%time
selectolax_default(all_html)
# Out:
# CPU times: user 506 ms, sys: 9.99 ms, total: 516 ms
# Wall time: 514 ms

# %%
# %%time
selectolax_lexbor(all_html)
# Out:
# CPU times: user 400 ms, sys: 0 ns, total: 400 ms
# Wall time: 398 ms

# %% [markdown]
# # Problems
#
# * No XPATH
# * API a little wonky
#     (Compare to parsel)
